# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\N.NAGESH\Desktop\Maven Challenge\candy-data.csv')

# %%
data.head()
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %%
data.shape
# Out:
# (85, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   competitorname    85 non-null     object
#  1   chocolate         85 non-null     int64
#  2   fruity            85 non-null     int64
#  3   caramel           85 non-null     int64
#  4   peanutyalmondy    85 non-null     int64
#  5   nougat            85 non-null     int64
#  6   crispedricewafer  85 non-null     int64
#  7   hard              85 non-null     int64
#  8   bar               85 non-null     int64
#  9   pluribus          85 non-null     int64
#  10  sugarpercent      85 non-null     float64
#  11  pricepercent      85 non-null     float64
#  12  winpercent        85 non-null     float64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 8.8+ KB

# %%
data.columns
# Out:
# Index(['competitorname', 'chocolate', 'fruity', 'caramel', 'peanutyalmondy',
#        'nougat', 'crispedricewafer', 'hard', 'bar', 'pluribus', 'sugarpercent',
#        'pricepercent', 'winpercent'],
#       dtype='object')

# %%
data.iloc[:6,0:2]
# Out:
#   competitorname  chocolate
# 0      100 Grand          1
# 1   3 Musketeers          1
# 2       One dime          0
# 3    One quarter          0
# 4      Air Heads          0
# 5     Almond Joy          1

# %%
# To see a list of unique values and how often they occur in the dataset, we can use the value_counts() method:
data.competitorname.value_counts()
data.competitorname.unique()
# Out:
# array(['100 Grand', '3 Musketeers', 'One dime', 'One quarter',
#        'Air Heads', 'Almond Joy', 'Baby Ruth', 'Boston Baked Beans',
#        'Candy Corn', 'Caramel Apple Pops', 'Charleston Chew',
#        'Chewey Lemonhead Fruit Mix', 'Chiclets', 'Dots', 'Dum Dums',
#        'Fruit Chews', 'Fun Dip', 'Gobstopper', 'Haribo Gold Bears',
#        'Haribo Happy Cola', 'Haribo Sour Bears', 'Haribo Twin Snakes',
#        "Hershey's Kisses", "Hershey's Krackel",
#        "Hershey's Milk Chocolate", "Hershey's Special Dark", 'Jawbusters',
#        'Junior Mints', 'Kit Kat', 'Laffy Taffy', 'Lemonhead',
#        'Lifesavers big ring gummies', "Peanut butter M&M's", "M&M's",
#        'Mike & Ike', 'Milk Duds', 'Milky Way', 'Milky Way Midnight',
#        'Milky Way Simply Caramel', 'Mounds', 'Mr Good Bar', 'Nerds',
#        'Nestle Butterfinger', 'Nestle Crunch', 'Nik L Nip', 'Now & Later',
#        'Payday', 'Peanut M&Ms', 'Pixie Sticks', 'Pop Rocks', 'Red vines',
# ...

# %%
data.describe()
# Out:
#        chocolate     fruity    caramel  peanutyalmondy     nougat  \
# count  85.000000  85.000000  85.000000       85.000000  85.000000
# mean    0.435294   0.447059   0.164706        0.164706   0.082353
# std     0.498738   0.500140   0.373116        0.373116   0.276533
# min     0.000000   0.000000   0.000000        0.000000   0.000000
# 25%     0.000000   0.000000   0.000000        0.000000   0.000000
# 50%     0.000000   0.000000   0.000000        0.000000   0.000000
# 75%     1.000000   1.000000   0.000000        0.000000   0.000000
# max     1.000000   1.000000   1.000000        1.000000   1.000000
#
#        crispedricewafer       hard        bar   pluribus  sugarpercent  \
# count         85.000000  85.000000  85.000000  85.000000     85.000000
# mean           0.082353   0.176471   0.247059   0.517647      0.478647
# std            0.276533   0.383482   0.433861   0.502654      0.282778
# min            0.000000   0.000000   0.000000   0.000000      0.011000
# ...

# %%
filtered_data = data[data['winpercent'] > 60]
filtered_data['competitorname']
# Out:
# 0                       100 Grand
# 1                    3 Musketeers
# 23              Hershey's Krackel
# 28                        Kit Kat
# 32            Peanut butter M&M's
# 33                          M&M's
# 36                      Milky Way
# 37             Milky Way Midnight
# 38       Milky Way Simply Caramel
# 42            Nestle Butterfinger
# 43                  Nestle Crunch
# 47                    Peanut M&Ms
# 51             Reese's Miniatures
# 52      Reese's Peanut Butter cup
# 53                 Reese's pieces
# 54    Reese's stuffed with pieces
# 56                           Rolo
# 60              Skittles original
# 64                       Snickers
# 68                      Starburst
# 79                           Twix
# Name: competitorname, dtype: object

# %%
data[data['winpercent'] > 80]
# Out:
#                competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 51         Reese's Miniatures          1       0        0               1
# 52  Reese's Peanut Butter cup          1       0        0               1
# 79                       Twix          1       0        1               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 51       0                 0     0    0         0         0.034         0.279
# 52       0                 0     0    0         0         0.720         0.651
# 79       0                 1     0    1         0         0.546         0.906
#
#     winpercent
# 51   81.866257
# 52   84.180290
# 79   81.642914

# %% [markdown]
# Twix -- choclate, caramel, crispedwafer, bar.

# %%
data.drop('chocolate',axis = 1,inplace=True)
data.drop('caramel',axis = 1,inplace=True)
data.drop('crispedricewafer',axis = 1,inplace=True)
data.drop('bar',axis = 1,inplace=True)

# %%
data[data['winpercent'] > 10]
# Out:
#                 competitorname  fruity  peanutyalmondy  nougat  hard  \
# 0                    100 Grand       0               0       0     0
# 1                 3 Musketeers       0               0       1     0
# 2                     One dime       0               0       0     0
# 3                  One quarter       0               0       0     0
# 4                    Air Heads       1               0       0     0
# ..                         ...     ...             ...     ...   ...
# 80                   Twizzlers       1               0       0     0
# 81                    Warheads       1               0       0     1
# 82        Welch's Fruit Snacks       1               0       0     0
# 83  Werther's Original Caramel       0               0       0     1
# 84                    Whoppers       0               0       0     0
#
#     pluribus  sugarpercent  pricepercent  winpercent
# 0          0         0.732         0.860   66.971725
# ...

# %% [markdown]
# Starburst -- fruity, pluribus

# %%
data.drop('fruity',axis = 1,inplace=True)

data.drop('pluribus',axis = 1,inplace=True)

# %%
data[data.peanutyalmondy == 1]
# Out:
#                  competitorname  peanutyalmondy  nougat  hard  sugarpercent  \
# 5                    Almond Joy               1       0     0         0.465
# 6                     Baby Ruth               1       1     0         0.604
# 7            Boston Baked Beans               1       0     0         0.313
# 32          Peanut butter M&M's               1       0     0         0.825
# 40                  Mr Good Bar               1       0     0         0.313
# 42          Nestle Butterfinger               1       0     0         0.604
# 46                       Payday               1       1     0         0.465
# 47                  Peanut M&Ms               1       0     0         0.593
# 51           Reese's Miniatures               1       0     0         0.034
# 52    Reese's Peanut Butter cup               1       0     0         0.720
# 53               Reese's pieces               1       0     0         0.406
# ...

# %% [markdown]
# Snickers -- peanutyalmondy, nougat

# %% [markdown]
# Therefore the 3 choclate with the most features covered are
# Twix -- choclate, caramel, crispedwafer, bar
# Starburst -- fruity, pluribus
# Snickers -- peanutyalmondy, nougat

# %%
data = pd.read_csv(r'C:\Users\N.NAGESH\Desktop\Maven Challenge\candy-data.csv',index_col='competitorname')

# %% [markdown]
# Note: in explicit indexing u can access the specified row with their index
#
#      if we dont specify the index column during reading of the csv file automatically numbers are assigned as indexes

# %%
data.loc[['Twix','Snickers','Starburst'],:]
# Out:
#                 chocolate  fruity  caramel  peanutyalmondy  nougat  \
# competitorname
# Twix                    1       0        1               0       0
# Snickers                1       0        1               1       1
# Starburst               0       1        0               0       0
#
#                 crispedricewafer  hard  bar  pluribus  sugarpercent  \
# competitorname
# Twix                           1     0    1         0         0.546
# Snickers                       0     0    1         0         0.546
# Starburst                      0     0    0         1         0.151
#
#                 pricepercent  winpercent
# competitorname
# Twix                   0.906   81.642914
# Snickers               0.651   76.673782
# Starburst              0.220   67.037628
